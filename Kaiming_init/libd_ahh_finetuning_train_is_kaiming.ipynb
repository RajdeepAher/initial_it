# %%
pip install -q datasets transformers[torch] evaluate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.6 MB/s eta 0:00:00

# %%
from datasets import load_dataset
dataset = load_dataset("glue", "mrpc")
dataset
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/35.3k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/649k [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/75.7k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/308k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3668 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/408 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1725 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['sentence1', 'sentence2', 'label', 'idx'],
#         num_rows: 3668
#     })
#     validation: Dataset({
#         features: ['sentence1', 'sentence2', 'label', 'idx'],
#         num_rows: 408
#     })
#     test: Dataset({
#         features: ['sentence1', 'sentence2', 'label', 'idx'],
#         num_rows: 1725
#     })
# })

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained( "bert-base-uncased")
mapped_dataset = dataset.map(lambda x: tokenizer(x["sentence1"], x["sentence2"]), batched = True)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Map:   0%|          | 0/3668 [00:00<?, ? examples/s]
# Map:   0%|          | 0/408 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1725 [00:00<?, ? examples/s]

# %%
from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
from transformers import AutoModelForSequenceClassification

model = AutoModelForSequenceClassification.from_pretrained("bert-base-uncased")
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import TrainingArguments
import evaluate
import numpy as np
def compute_metrics(eval_preds):
  metric = evaluate.load("glue", "mrpc")
  logits, labels = eval_preds
  predictions = np.argmax(logits, axis =-1)
  return metric.compute(predictions=predictions, references = labels)
#train_args = TrainingArguments("test-run-1", evaluation_strategy= "epoch")
from transformers import TrainingArguments

train_args = TrainingArguments(
    output_dir='./results',                   # directory to save results
    evaluation_strategy="epoch",              # evaluation at the end of each epoch
    learning_rate=1e-2,                      # learning rate
    per_device_train_batch_size=16,           # batch size for training
    weight_decay=0.01,                        # strength of weight decay
    logging_dir='./logs',                     # directory for storing logs
    logging_steps=10,
    seed=42,                                   # random seed for reproducibility
    adam_beta1=0.9,                           # beta1 for Adam optimizer
    adam_beta2=0.999,                         # beta2 for Adam optimizer
    adam_epsilon=1e-08,                       # epsilon for Adam optimizer
    lr_scheduler_type="cosine_with_restarts",
    num_train_epochs=10,
    warmup_steps=500,
    gradient_accumulation_steps=2
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
model
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
from lidb_but_train_is_small_randn import myLoRALayer
import lidb_but_train_is_small_randn as lora

# %%
def apply_lora_to_bert(bert_model, r=16, lora_a = 32, lora_b =32, lora_alpha=16, lora_dropout=0.02):
    for layer in bert_model.bert.encoder.layer:
        # Apply LoRA to the query and key projection layers in self-attention
        layer.attention.self.query = lora.Linear(
            layer.attention.self.query.in_features,
            layer.attention.self.query.out_features,
            lora_a = lora_a,
            lora_b=lora_b,
            r=r, lora_alpha=lora_alpha, lora_dropout=lora_dropout
        )
        layer.attention.self.key = lora.Linear(
            layer.attention.self.key.in_features,
            layer.attention.self.key.out_features,
            lora_a = lora_a,
            lora_b=lora_b,
            r=r, lora_alpha=lora_alpha, lora_dropout=lora_dropout
        )
        layer.attention.self.value= lora.Linear(
            layer.attention.self.value.in_features,
            layer.attention.self.value.out_features,
            lora_a = lora_a,
            lora_b=lora_b,
            r=r, lora_alpha=lora_alpha, lora_dropout=lora_dropout
        )
    return bert_model

# Apply LoRA to the BERT model's attention layers
model = apply_lora_to_bert(model)
#16,32,32 is decent

# %%
model
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(
#                 in_features=768, out_features=768, bias=True
#                 (lora_dropout): Dropout(p=0.02, inplace=False)
#               )
#               (key): Linear(
#                 in_features=768, out_features=768, bias=True
#                 (lora_dropout): Dropout(p=0.02, inplace=False)
#               )
#               (value): Linear(
#                 in_features=768, out_features=768, bias=True
#                 (lora_dropout): Dropout(p=0.02, inplace=False)
#               )
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
from utils import mark_only_lora_as_trainable

# %%
# Mark only the LoRA parameters as trainable
mark_only_lora_as_trainable(model)

# %%
def count_trainable_params(model):
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return trainable_params

# %%
def show_trainable_params(model):
    print("Trainable parameters (requires_grad=True):")
    for name, param in model.named_parameters():
        if param.requires_grad:
            print(f"{name}: {param.shape}")

# %%
print(count_trainable_params(model))
show_trainable_params(model)
# Out:
# 36864
# Trainable parameters (requires_grad=True):
# bert.encoder.layer.0.attention.self.query.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.0.attention.self.query.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.0.attention.self.key.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.0.attention.self.key.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.0.attention.self.value.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.0.attention.self.value.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.1.attention.self.query.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.1.attention.self.query.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.1.attention.self.key.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.1.attention.self.key.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.1.attention.self.value.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.1.attention.self.value.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.2.attention.self.query.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.2.attention.self.query.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.2.attention.self.key.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.2.attention.self.key.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.2.attention.self.value.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.2.attention.self.value.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.3.attention.self.query.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.3.attention.self.query.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.3.attention.self.key.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.3.attention.self.key.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.3.attention.self.value.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.3.attention.self.value.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.4.attention.self.query.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.4.attention.self.query.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.4.attention.self.key.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.4.attention.self.key.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.4.attention.self.value.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.4.attention.self.value.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.5.attention.self.query.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.5.attention.self.query.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.5.attention.self.key.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.5.attention.self.key.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.5.attention.self.value.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.5.attention.self.value.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.6.attention.self.query.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.6.attention.self.query.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.6.attention.self.key.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.6.attention.self.key.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.6.attention.self.value.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.6.attention.self.value.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.7.attention.self.query.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.7.attention.self.query.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.7.attention.self.key.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.7.attention.self.key.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.7.attention.self.value.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.7.attention.self.value.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.8.attention.self.query.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.8.attention.self.query.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.8.attention.self.key.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.8.attention.self.key.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.8.attention.self.value.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.8.attention.self.value.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.9.attention.self.query.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.9.attention.self.query.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.9.attention.self.key.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.9.attention.self.key.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.9.attention.self.value.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.9.attention.self.value.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.10.attention.self.query.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.10.attention.self.query.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.10.attention.self.key.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.10.attention.self.key.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.10.attention.self.value.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.10.attention.self.value.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.11.attention.self.query.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.11.attention.self.query.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.11.attention.self.key.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.11.attention.self.key.lora_B_train: torch.Size([32, 16])
# bert.encoder.layer.11.attention.self.value.lora_A_train: torch.Size([16, 32])
# bert.encoder.layer.11.attention.self.value.lora_B_train: torch.Size([32, 16])

# %%
from transformers import Trainer

trainer = Trainer(
    model = model,
    args = train_args,
    train_dataset = mapped_dataset["train"],
    eval_dataset = mapped_dataset["validation"],
    data_collator = data_collator,
    tokenizer=tokenizer,
    compute_metrics = compute_metrics,

)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='1150' max='1150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1150/1150 06:34, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.616700</td>
#       <td>0.630956</td>
#       <td>0.671569</td>
#       <td>0.802360</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.665200</td>
#       <td>0.632015</td>
#       <td>0.671569</td>
#       <td>0.801775</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.657900</td>
#       <td>0.632630</td>
#       <td>0.674020</td>
#       <td>0.804124</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.688900</td>
#       <td>0.634803</td>
#       <td>0.671569</td>
#       <td>0.803519</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.688200</td>
#       <td>0.629701</td>
#       <td>0.681373</td>
#       <td>0.810496</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.621400</td>
#       <td>0.626333</td>
#       <td>0.681373</td>
#       <td>0.810496</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.635800</td>
#       <td>0.623977</td>
#       <td>0.683824</td>
#       <td>0.812227</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.616100</td>
#       <td>0.624079</td>
#       <td>0.683824</td>
#       <td>0.812227</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.619300</td>
#       <td>0.623988</td>
#       <td>0.683824</td>
#       <td>0.812227</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.669900</td>
#       <td>0.623978</td>
#       <td>0.683824</td>
#       <td>0.812227</td>
#     </tr>
#   </tbody>
# </table><p>
# Downloading builder script:   0%|          | 0.00/5.75k [00:00<?, ?B/s]
# TrainOutput(global_step=1150, training_loss=0.6468552191361137, metrics={'train_runtime': 396.2292, 'train_samples_per_second': 92.573, 'train_steps_per_second': 2.902, 'total_flos': 1462911021454608.0, 'train_loss': 0.6468552191361137, 'epoch': 10.0})

# %%
import numpy
preds = trainer.predict(mapped_dataset["test"])
logits, labels, _ = preds
predictions = numpy.argmax(logits, axis =-1)
metric = evaluate.load("glue", "mrpc")
metric.compute(predictions = predictions, references = labels)
# Out:
# {'accuracy': 0.664927536231884, 'f1': 0.7987465181058496}
